# %% [markdown]
# #######################################################################################
# # GROUP PROJECT 2 - ETL
# ## Students:  James Dietz  |  Rafael Santos
# ### DATA ANALYTICS AND VISUALIZATION COHORT 3
# #######################################################################################

# %% [markdown]
# ## Summary:
#
# The focus on the project was on Extracting, Transforming, and Loading (ETL) international data pertaining to agricultural land resources, cereal crop yields, and cereal crop commodity markets and prices.  The data sources came from the World Bank and the Kaggle.  Each data source was organized by country level data (more details are provided in the Transform Section).
#
# We believe that the combined ETL data source could be useful in international comparative analyses of the agricultural resources, cereal crop yields, and price levels.  Data sources varied in the year of most recent available.  We chose to use the most recent year available, 2016, that was common to all datasets:
#
# World Bank URL:  https://data.worldbank.org/topic/agriculture-and-rural-development
#
# Kaggle URL: https://www.kaggle.com/jboysen/global-food-prices/version/1
#
#
# We took three major steps to build the database:
#
# 1) Extract:
# * downloaded the datasets available in CSV files
# * reviewed the data using Pandas to identify meaningful fields for the purpose of this project.
#
# 2) Transform:
# * extracted the meaningful fields into dataframes to manipulate the data.
# * created and/or modified dataframe indexes to be set as country code IDs (using ISO A3 standard).
# * merged dataframes
# * created final tables to load into SQL
#
#   AND/OR
#
# * merged loaded tables within SQL enviroment
#
# 3) Load:
# * manually created the database schema in MySQL
# * using SQL Alchemy:
#  * created the connection between Pandas (Python) environment and the SQL database.
#  * loaded the Pandas dataframe data into the SQL database.
#
# The details, including the results obtained, are either described or provided below along with the code used.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#used for Global Food Price only
import numpy as np

# %% [markdown]
# ### 1) EXTRACT:  WORLD BANK (WB)
#
# The data were downloaded from the above WB website.  Two datasets were downloaded—(1) cereal crop yields per country in KG per hectacre [cereal_yield], and (2) percent of total country land area that is devoted to agriculture by country [agriculture_land].
#
# Data sets were downloaded as .csv files and were read into pandas via this Jupyter Notebook.

# %% [markdown]
# ### 1) EXTRACT:  WB DATA - Cereal Yield

# %%
# Loaded data from CSV file into Pandas Dataframe
cereal_yield = "cereal_yield.csv"
cereal_yield_raw_df = pd.read_csv(cereal_yield)
cereal_yield_raw_df.head()
# Out:
#   Country Name Country Code                 Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 1  Afghanistan          AFG  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 2       Angola          AGO  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 3      Albania          ALB  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 4      Andorra          AND  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
#
#    1960    1961    1962   1963    1964    1965  ...     2009    2010    2011  \
# 0   NaN     NaN     NaN    NaN     NaN     NaN  ...      NaN     NaN     NaN
# 1   NaN  1115.1  1079.0  985.8  1082.8  1098.9  ...   2040.7  2011.1  1659.9
# 2   NaN   828.0   830.3  798.4   875.8   932.0  ...    571.4   629.3   662.4
# 3   NaN   845.2   941.8  982.3  1023.3  1037.3  ...   4315.3  4761.8  4750.7
# 4   NaN     NaN     NaN    NaN     NaN     NaN  ...      NaN     NaN     NaN
#
#      2012    2013    2014    2015    2016    2017  2018
# 0     NaN     NaN     NaN     NaN     NaN     NaN   NaN
# 1  2029.6  2048.5  2017.5  2133.0  1981.6  2024.7   NaN
# 2   552.0   814.4   888.3   982.0   934.1   904.5   NaN
# 3  4883.8  4949.8  4892.6  4873.8  4716.4  4813.0   NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN   NaN
#
# [5 rows x 63 columns]

# %% [markdown]
# ### 2) TRANSFORM: WORLD BANK (WB)
#
# The data sets were made into two separate dataframes (DFs) in the step above, and then were transformed by deleting extraneous columns, which including a number of indicator codes unique to WB data systems and data for years not used in this project.

# %% [markdown]
# ### 2) TRANSFORM:  WB DATA - Cereal Yield

# %%
cereal_yield_raw_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
# Create a filtered dataframe from specific columns
cereal_cols = ["Country Name", "Country Code", "2016"]
cereal_yield_df= cereal_yield_raw_df[cereal_cols].copy()

# Rename the column headers
cereal_yield_df = cereal_yield_df.rename(columns={"Country Name": "country_name",
                                                        "Country Code": "country_code",
                                                         "2016": "yield"})

# Clean the data by dropping duplicates and setting the index
#premise_transformed.drop_duplicates("id", inplace=True)
cereal_yield_df.set_index("country_code", inplace=True)

cereal_yield_df
# Out:
#                                                    country_name         yield
# country_code
# ABW                                                       Aruba           NaN
# AFG                                                 Afghanistan   1981.600000
# AGO                                                      Angola    934.100000
# ALB                                                     Albania   4716.400000
# AND                                                     Andorra           NaN
# ARB                                                  Arab World   1744.945443
# ARE                                        United Arab Emirates  28130.100000
# ARG                                                   Argentina   5203.500000
# ARM                                                     Armenia   3076.100000
# ASM                                              American Samoa           NaN
# ATG                                         Antigua and Barbuda   1586.700000
# AUS                                                   Australia   2075.200000
# AUT                                                     Austria   7244.800000
# AZE                                                  Azerbaijan   3004.800000
# BDI                                                     Burundi   1524.800000
# BEL                                                     Belgium   6984.800000
# BEN                                                       Benin   1455.900000
# BFA                                                Burkina Faso   1136.800000
# BGD                                                  Bangladesh   4601.000000
# BGR                                                    Bulgaria   4817.800000
# BHR                                                     Bahrain           NaN
# BHS                                                Bahamas, The   8526.100000
# BIH                                      Bosnia and Herzegovina   5191.700000
# BLR                                                     Belarus   3207.300000
# BLZ                                                      Belize   3164.600000
# BMU                                                     Bermuda           NaN
# BOL                                                     Bolivia   2111.300000
# BRA                                                      Brazil   4180.800000
# BRB                                                    Barbados   2852.900000
# BRN                                           Brunei Darussalam   1558.400000
# ...                                                         ...           ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...   4185.291571
# TLS                                                 Timor-Leste   2394.100000
# TMN           Middle East & North Africa (IDA & IBRD countries)   2587.140546
# TON                                                       Tonga           NaN
# TSA                                     South Asia (IDA & IBRD)   3131.504062
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)   1399.718131
# TTO                                         Trinidad and Tobago   1483.000000
# TUN                                                     Tunisia   1542.200000
# TUR                                                      Turkey   3105.400000
# TUV                                                      Tuvalu           NaN
# TZA                                                    Tanzania   1546.400000
# UGA                                                      Uganda   1885.800000
# UKR                                                     Ukraine   4651.600000
# UMC                                         Upper middle income   4207.098221
# URY                                                     Uruguay   4940.700000
# USA                                               United States   8144.600000
# UZB                                                  Uzbekistan   4585.600000
# VCT                              St. Vincent and the Grenadines  24742.900000
# VEN                                               Venezuela, RB   3426.900000
# VGB                                      British Virgin Islands           NaN
# VIR                                       Virgin Islands (U.S.)           NaN
# VNM                                                     Vietnam   5441.000000
# VUT                                                     Vanuatu    609.100000
# WLD                                                       World   3967.029197
# WSM                                                       Samoa           NaN
# XKX                                                      Kosovo           NaN
# YEM                                                 Yemen, Rep.    687.000000
# ZAF                                                South Africa   3818.600000
# ZMB                                                      Zambia   2417.700000
# ZWE                                                    Zimbabwe    581.800000
#
# [264 rows x 2 columns]

# %% [markdown]
# ### 2) EXTRACT:  WB DATA - Percentage of Agriculture Land

# %%
agriculture_land = "agriculture_land.csv"
agriculture_land_raw_df = pd.read_csv(agriculture_land)
agriculture_land_raw_df.head()
# Out:
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW  Agricultural land (% of land area)
# 1  Afghanistan          AFG  Agricultural land (% of land area)
# 2       Angola          AGO  Agricultural land (% of land area)
# 3      Albania          ALB  Agricultural land (% of land area)
# 4      Andorra          AND  Agricultural land (% of land area)
#
#    Indicator Code  1960       1961       1962       1963       1964  \
# 0  AG.LND.AGRI.ZS   NaN  11.111111  11.111111  11.111111  11.111111
# 1  AG.LND.AGRI.ZS   NaN  57.745918  57.837821  57.914407  58.010906
# 2  AG.LND.AGRI.ZS   NaN  45.857063  45.881126  45.897169  45.921232
# 3  AG.LND.AGRI.ZS   NaN  44.963504  44.963504  45.000000  44.890511
# 4  AG.LND.AGRI.ZS   NaN  55.319149  55.319149  55.319149  55.319149
#
#         1965  ...        2009       2010       2011       2012       2013  \
# 0  11.111111  ...   11.111111  11.111111  11.111111  11.111111  11.111111
# 1  58.013969  ...   58.067580  58.069111  58.067580  58.067580  58.067580
# 2  45.937274  ...   46.755434  46.835646  47.316917  47.316917  47.477340
# 3  45.145985  ...   43.843067  43.843067  43.832117  43.843067  43.332119
# 4  55.319149  ...   44.191490  42.063831  42.063831  39.914894  40.021275
#
#         2014       2015       2016  2017  2018
# 0  11.111111  11.111111  11.111111   NaN   NaN
# 1  58.067580  58.067580  58.067580   NaN   NaN
# 2  47.477340  47.477340  47.477340   NaN   NaN
# 3  42.857301  42.857666  43.127735   NaN   NaN
# 4  40.021275  40.021275  39.957448   NaN   NaN
#
# [5 rows x 63 columns]

# %% [markdown]
# ### 2) TRANSFORM:  WB DATA - Percentage of Agriculture Land

# %%
agriculture_land_raw_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
# Create a filtered dataframe from specific columns
ag_cols = ["Country Name", "Country Code", "2016"]
agriculture_land_df= agriculture_land_raw_df[ag_cols].copy()

# Rename the column headers
agriculture_land_df = agriculture_land_df.rename(columns={"Country Name": "country_name",
                                                        "Country Code": "country_code",
                                                         "2016": "percent_land"})

# Clean the data by dropping duplicates and setting the index
#premise_transformed.drop_duplicates("id", inplace=True)
agriculture_land_df.set_index("country_code", inplace=True)

agriculture_land_df
# Out:
#                                                    country_name  percent_land
# country_code
# ABW                                                       Aruba     11.111111
# AFG                                                 Afghanistan     58.067580
# AGO                                                      Angola     47.477340
# ALB                                                     Albania     43.127735
# AND                                                     Andorra     39.957448
# ARB                                                  Arab World     36.610850
# ARE                                        United Arab Emirates      5.474514
# ARG                                                   Argentina     54.335712
# ARM                                                     Armenia     58.897086
# ASM                                              American Samoa     24.500000
# ATG                                         Antigua and Barbuda     20.454545
# AUS                                                   Australia     48.241944
# AUT                                                     Austria     32.356676
# AZE                                                  Azerbaijan     57.735575
# BDI                                                     Burundi     79.166667
# BEL                                                     Belgium     44.610305
# BEN                                                       Benin     33.256474
# BFA                                                Burkina Faso     44.225146
# BGD                                                  Bangladesh     70.632327
# BGR                                                    Bulgaria     46.250921
# BHR                                                     Bahrain     11.053985
# BHS                                                Bahamas, The      1.398601
# BIH                                      Bosnia and Herzegovina     43.144531
# BLR                                                     Belarus     42.035489
# BLZ                                                      Belize      7.014467
# BMU                                                     Bermuda      5.555556
# BOL                                                     Bolivia     34.787224
# BRA                                                      Brazil     33.924533
# BRB                                                    Barbados     23.255814
# BRN                                           Brunei Darussalam      2.732448
# ...                                                         ...           ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...     37.570951
# TLS                                                 Timor-Leste     25.554808
# TMN           Middle East & North Africa (IDA & IBRD countries)     22.843529
# TON                                                       Tonga     45.833333
# TSA                                     South Asia (IDA & IBRD)     56.806288
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)     43.685707
# TTO                                         Trinidad and Tobago     10.526316
# TUN                                                     Tunisia     64.836509
# TUR                                                      Turkey     49.799254
# TUV                                                      Tuvalu     59.999998
# TZA                                                    Tanzania     44.761797
# UGA                                                      Uganda     71.888091
# UKR                                                     Ukraine     71.665314
# UMC                                         Upper middle income     34.432395
# URY                                                     Uruguay     82.559705
# USA                                               United States     44.369068
# UZB                                                  Uzbekistan     62.929008
# VCT                              St. Vincent and the Grenadines     25.641026
# VEN                                               Venezuela, RB     24.488408
# VGB                                      British Virgin Islands     46.666667
# VIR                                       Virgin Islands (U.S.)     11.428571
# VNM                                                     Vietnam     39.275002
# VUT                                                     Vanuatu     15.340443
# WLD                                                       World     37.430740
# WSM                                                       Samoa     12.367491
# XKX                                                      Kosovo           NaN
# YEM                                                 Yemen, Rep.     44.597231
# ZAF                                                South Africa     79.830021
# ZMB                                                      Zambia     32.063923
# ZWE                                                    Zimbabwe     41.876696
#
# [264 rows x 2 columns]

# %% [markdown]
# ### 2) TRANSFORM:  WORLD BANK DATA - Merging datasets into a single dataframe table

# %%
cereal_df = cereal_yield_df.merge(agriculture_land_df, left_on='country_code', right_on='country_code')
cereal_df
# Out:
#                                                  country_name_x         yield  \
# country_code
# ABW                                                       Aruba           NaN
# AFG                                                 Afghanistan   1981.600000
# AGO                                                      Angola    934.100000
# ALB                                                     Albania   4716.400000
# AND                                                     Andorra           NaN
# ARB                                                  Arab World   1744.945443
# ARE                                        United Arab Emirates  28130.100000
# ARG                                                   Argentina   5203.500000
# ARM                                                     Armenia   3076.100000
# ASM                                              American Samoa           NaN
# ATG                                         Antigua and Barbuda   1586.700000
# AUS                                                   Australia   2075.200000
# AUT                                                     Austria   7244.800000
# AZE                                                  Azerbaijan   3004.800000
# BDI                                                     Burundi   1524.800000
# BEL                                                     Belgium   6984.800000
# BEN                                                       Benin   1455.900000
# BFA                                                Burkina Faso   1136.800000
# BGD                                                  Bangladesh   4601.000000
# BGR                                                    Bulgaria   4817.800000
# BHR                                                     Bahrain           NaN
# BHS                                                Bahamas, The   8526.100000
# BIH                                      Bosnia and Herzegovina   5191.700000
# BLR                                                     Belarus   3207.300000
# BLZ                                                      Belize   3164.600000
# BMU                                                     Bermuda           NaN
# BOL                                                     Bolivia   2111.300000
# BRA                                                      Brazil   4180.800000
# BRB                                                    Barbados   2852.900000
# BRN                                           Brunei Darussalam   1558.400000
# ...                                                         ...           ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...   4185.291571
# TLS                                                 Timor-Leste   2394.100000
# TMN           Middle East & North Africa (IDA & IBRD countries)   2587.140546
# TON                                                       Tonga           NaN
# TSA                                     South Asia (IDA & IBRD)   3131.504062
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)   1399.718131
# TTO                                         Trinidad and Tobago   1483.000000
# TUN                                                     Tunisia   1542.200000
# TUR                                                      Turkey   3105.400000
# TUV                                                      Tuvalu           NaN
# TZA                                                    Tanzania   1546.400000
# UGA                                                      Uganda   1885.800000
# UKR                                                     Ukraine   4651.600000
# UMC                                         Upper middle income   4207.098221
# URY                                                     Uruguay   4940.700000
# USA                                               United States   8144.600000
# UZB                                                  Uzbekistan   4585.600000
# VCT                              St. Vincent and the Grenadines  24742.900000
# VEN                                               Venezuela, RB   3426.900000
# VGB                                      British Virgin Islands           NaN
# VIR                                       Virgin Islands (U.S.)           NaN
# VNM                                                     Vietnam   5441.000000
# VUT                                                     Vanuatu    609.100000
# WLD                                                       World   3967.029197
# WSM                                                       Samoa           NaN
# XKX                                                      Kosovo           NaN
# YEM                                                 Yemen, Rep.    687.000000
# ZAF                                                South Africa   3818.600000
# ZMB                                                      Zambia   2417.700000
# ZWE                                                    Zimbabwe    581.800000
#
#                                                  country_name_y  percent_land
# country_code
# ABW                                                       Aruba     11.111111
# AFG                                                 Afghanistan     58.067580
# AGO                                                      Angola     47.477340
# ALB                                                     Albania     43.127735
# AND                                                     Andorra     39.957448
# ARB                                                  Arab World     36.610850
# ARE                                        United Arab Emirates      5.474514
# ARG                                                   Argentina     54.335712
# ARM                                                     Armenia     58.897086
# ASM                                              American Samoa     24.500000
# ATG                                         Antigua and Barbuda     20.454545
# AUS                                                   Australia     48.241944
# AUT                                                     Austria     32.356676
# AZE                                                  Azerbaijan     57.735575
# BDI                                                     Burundi     79.166667
# BEL                                                     Belgium     44.610305
# BEN                                                       Benin     33.256474
# BFA                                                Burkina Faso     44.225146
# BGD                                                  Bangladesh     70.632327
# BGR                                                    Bulgaria     46.250921
# BHR                                                     Bahrain     11.053985
# BHS                                                Bahamas, The      1.398601
# BIH                                      Bosnia and Herzegovina     43.144531
# BLR                                                     Belarus     42.035489
# BLZ                                                      Belize      7.014467
# BMU                                                     Bermuda      5.555556
# BOL                                                     Bolivia     34.787224
# BRA                                                      Brazil     33.924533
# BRB                                                    Barbados     23.255814
# BRN                                           Brunei Darussalam      2.732448
# ...                                                         ...           ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...     37.570951
# TLS                                                 Timor-Leste     25.554808
# TMN           Middle East & North Africa (IDA & IBRD countries)     22.843529
# TON                                                       Tonga     45.833333
# TSA                                     South Asia (IDA & IBRD)     56.806288
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)     43.685707
# TTO                                         Trinidad and Tobago     10.526316
# TUN                                                     Tunisia     64.836509
# TUR                                                      Turkey     49.799254
# TUV                                                      Tuvalu     59.999998
# TZA                                                    Tanzania     44.761797
# UGA                                                      Uganda     71.888091
# UKR                                                     Ukraine     71.665314
# UMC                                         Upper middle income     34.432395
# URY                                                     Uruguay     82.559705
# USA                                               United States     44.369068
# UZB                                                  Uzbekistan     62.929008
# VCT                              St. Vincent and the Grenadines     25.641026
# VEN                                               Venezuela, RB     24.488408
# VGB                                      British Virgin Islands     46.666667
# VIR                                       Virgin Islands (U.S.)     11.428571
# VNM                                                     Vietnam     39.275002
# VUT                                                     Vanuatu     15.340443
# WLD                                                       World     37.430740
# WSM                                                       Samoa     12.367491
# XKX                                                      Kosovo           NaN
# YEM                                                 Yemen, Rep.     44.597231
# ZAF                                                South Africa     79.830021
# ZMB                                                      Zambia     32.063923
# ZWE                                                    Zimbabwe     41.876696
#
# [264 rows x 4 columns]

# %% [markdown]
# ### 2) TRANSFORM:  WORLD BANK DATA - Cleaning up

# %%
cereal_df.drop(columns=['country_name_y'], inplace=True)

# %%
cereal_df.rename(index=str, columns={"country_name_x": "country_name"})
# Out:
#                                                    country_name         yield  \
# country_code
# ABW                                                       Aruba           NaN
# AFG                                                 Afghanistan   1981.600000
# AGO                                                      Angola    934.100000
# ALB                                                     Albania   4716.400000
# AND                                                     Andorra           NaN
# ARB                                                  Arab World   1744.945443
# ARE                                        United Arab Emirates  28130.100000
# ARG                                                   Argentina   5203.500000
# ARM                                                     Armenia   3076.100000
# ASM                                              American Samoa           NaN
# ATG                                         Antigua and Barbuda   1586.700000
# AUS                                                   Australia   2075.200000
# AUT                                                     Austria   7244.800000
# AZE                                                  Azerbaijan   3004.800000
# BDI                                                     Burundi   1524.800000
# BEL                                                     Belgium   6984.800000
# BEN                                                       Benin   1455.900000
# BFA                                                Burkina Faso   1136.800000
# BGD                                                  Bangladesh   4601.000000
# BGR                                                    Bulgaria   4817.800000
# BHR                                                     Bahrain           NaN
# BHS                                                Bahamas, The   8526.100000
# BIH                                      Bosnia and Herzegovina   5191.700000
# BLR                                                     Belarus   3207.300000
# BLZ                                                      Belize   3164.600000
# BMU                                                     Bermuda           NaN
# BOL                                                     Bolivia   2111.300000
# BRA                                                      Brazil   4180.800000
# BRB                                                    Barbados   2852.900000
# BRN                                           Brunei Darussalam   1558.400000
# ...                                                         ...           ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...   4185.291571
# TLS                                                 Timor-Leste   2394.100000
# TMN           Middle East & North Africa (IDA & IBRD countries)   2587.140546
# TON                                                       Tonga           NaN
# TSA                                     South Asia (IDA & IBRD)   3131.504062
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)   1399.718131
# TTO                                         Trinidad and Tobago   1483.000000
# TUN                                                     Tunisia   1542.200000
# TUR                                                      Turkey   3105.400000
# TUV                                                      Tuvalu           NaN
# TZA                                                    Tanzania   1546.400000
# UGA                                                      Uganda   1885.800000
# UKR                                                     Ukraine   4651.600000
# UMC                                         Upper middle income   4207.098221
# URY                                                     Uruguay   4940.700000
# USA                                               United States   8144.600000
# UZB                                                  Uzbekistan   4585.600000
# VCT                              St. Vincent and the Grenadines  24742.900000
# VEN                                               Venezuela, RB   3426.900000
# VGB                                      British Virgin Islands           NaN
# VIR                                       Virgin Islands (U.S.)           NaN
# VNM                                                     Vietnam   5441.000000
# VUT                                                     Vanuatu    609.100000
# WLD                                                       World   3967.029197
# WSM                                                       Samoa           NaN
# XKX                                                      Kosovo           NaN
# YEM                                                 Yemen, Rep.    687.000000
# ZAF                                                South Africa   3818.600000
# ZMB                                                      Zambia   2417.700000
# ZWE                                                    Zimbabwe    581.800000
#
#               percent_land
# country_code
# ABW              11.111111
# AFG              58.067580
# AGO              47.477340
# ALB              43.127735
# AND              39.957448
# ARB              36.610850
# ARE               5.474514
# ARG              54.335712
# ARM              58.897086
# ASM              24.500000
# ATG              20.454545
# AUS              48.241944
# AUT              32.356676
# AZE              57.735575
# BDI              79.166667
# BEL              44.610305
# BEN              33.256474
# BFA              44.225146
# BGD              70.632327
# BGR              46.250921
# BHR              11.053985
# BHS               1.398601
# BIH              43.144531
# BLR              42.035489
# BLZ               7.014467
# BMU               5.555556
# BOL              34.787224
# BRA              33.924533
# BRB              23.255814
# BRN               2.732448
# ...                    ...
# TLA              37.570951
# TLS              25.554808
# TMN              22.843529
# TON              45.833333
# TSA              56.806288
# TSS              43.685707
# TTO              10.526316
# TUN              64.836509
# TUR              49.799254
# TUV              59.999998
# TZA              44.761797
# UGA              71.888091
# UKR              71.665314
# UMC              34.432395
# URY              82.559705
# USA              44.369068
# UZB              62.929008
# VCT              25.641026
# VEN              24.488408
# VGB              46.666667
# VIR              11.428571
# VNM              39.275002
# VUT              15.340443
# WLD              37.430740
# WSM              12.367491
# XKX                    NaN
# YEM              44.597231
# ZAF              79.830021
# ZMB              32.063923
# ZWE              41.876696
#
# [264 rows x 3 columns]

# %%
agriculture_land_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264 entries, ABW to ZWE
# Data columns (total 2 columns):
# country_name    264 non-null object
# percent_land    254 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 6.2+ KB

# %% [markdown]
# ##  GLOBAL FOOD PRICE

# %% [markdown]
# ### 1) EXTRACT: GLOBAL FOOD PRICE
#
# * Imported the country code list from a previous project, as a CSV file
# * Downloaded from Kaggle website the CSV file for Global Food Price.

# %%
#Converting files from CSV to Pandas dataframe
countrycodes_file = "CountryCodesLookup.csv"
countrycodes = pd.read_csv(countrycodes_file, encoding="ISO-8859-1")
countrycodes = countrycodes.rename(columns={'COUNTRY':'country'})

food_price_file = "global-food-prices/wfp_market_food_prices.csv"
food_price = pd.read_csv(food_price_file, encoding="ISO-8859-1")
food_price.head()
# Out:
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id cm_name  \
# 0        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 1        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 2        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 3        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 4        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
#
#    cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  mp_year  mp_price  \
# 0      87      AFN     15  Retail      5      KG         1     2014      50.0
# 1      87      AFN     15  Retail      5      KG         2     2014      50.0
# 2      87      AFN     15  Retail      5      KG         3     2014      50.0
# 3      87      AFN     15  Retail      5      KG         4     2014      50.0
# 4      87      AFN     15  Retail      5      KG         5     2014      50.0
#
#   mp_commoditysource
# 0                WFP
# 1                WFP
# 2                WFP
# 3                WFP
# 4                WFP

# %% [markdown]
# ### 1) EXTRACT: GLOBAL FOOD PRICE
# ### - Filtering for interested year (2016).

# %%
#Filtering data for the year 2016
food_price2016 = food_price.loc[food_price['mp_year']==2016,\
                ['adm0_name','cur_name','cm_name','pt_name','um_name','mp_month','mp_year','mp_price']]
food_price2016.head()
# Out:
#       adm0_name cur_name cm_name pt_name um_name  mp_month  mp_year  mp_price
# 22  Afghanistan      AFN   Bread  Retail      KG         1     2016      55.5
# 23  Afghanistan      AFN   Bread  Retail      KG         2     2016      55.5
# 24  Afghanistan      AFN   Bread  Retail      KG         3     2016      55.5
# 25  Afghanistan      AFN   Bread  Retail      KG         4     2016      50.0
# 26  Afghanistan      AFN   Bread  Retail      KG         5     2016      50.0

# %% [markdown]
# ### 2) TRANSFORM:  GLOBAL FOOD PRICE
# ### - Cleaning up dataset upfront for improved readability of the code and data itself.

# %%
#Adjusting table headers and removing columns

table = pd.pivot_table(food_price2016, values=['mp_price'], \
                               index = ['adm0_name','cur_name','cm_name','um_name'],\
                               aggfunc={"mp_price": np.mean})

table = table.reset_index(level=['um_name'])  #convert pivot table indexes into columns
table = table.reset_index(level=['cm_name'])  #convert pivot table indexes into columns
table = table.reset_index(level=['cur_name'])  #convert pivot table indexes into columns
table = table.reset_index(level=['adm0_name'])  #convert pivot table indexes into columns

#Column names copied from the description provided at https://www.kaggle.com/jboysen/global-food-prices/version/1
table = table.rename(columns={'adm0_name':'country'})
table = table.rename(columns={'cur_name':'currency_ID'})
table = table.rename(columns={'cm_name':'commodity_purchased'})
table = table.rename(columns={'um_name':'unit_of_goods_measurement'})
table = table.rename(columns={'mp_price':'monthly_average_price_paid'})

table.head()
# Out:
#        country currency_ID                            commodity_purchased  \
# 0  Afghanistan         AFN                                          Bread
# 1  Afghanistan         AFN                                  Exchange rate
# 2  Afghanistan         AFN                                  Fuel (diesel)
# 3  Afghanistan         AFN                             Rice (low quality)
# 4  Afghanistan         AFN  Wage (non-qualified labour, non-agricultural)
#
#   unit_of_goods_measurement  monthly_average_price_paid
# 0                        KG                   44.749375
# 1                   USD/LCU                   67.790319
# 2                         L                   36.969922
# 3                        KG                   41.392708
# 4                       Day                  285.026042

# %% [markdown]
# ### 2) TRANSFORM: GLOBAL FOOD PRICE
#
# Note: An initial filter (using "df.LOC") for each food item by its name returned very few values. Reviewing the data, I noticed two meaningful details:
#
#   1) there were descriptions for more than one type of the same food
#
#   2) the unit measures were in some cases different.
#
# The decision was at this point was to keep the food item with highest price, and filter for all that rows containing (instead of equal) to the food item researched.
#
# #### Bread
# * Defined criteria and filtered data for the first food item chosen: bread
# * Merged the datasets in order to have standard Country ID associated to the table.
# * Cleaned up the data for irrelevant columns

# %%
#filtering table for all rows with the commodity
table_bread = table[table.commodity_purchased.str.contains('Bread', case=False)]

#sorting the list
table_bread = table_bread.sort_values(by=['country','monthly_average_price_paid'],ascending=True,na_position='first')

#dropping duplicated, keeping item with highest price (=last)
table_bread = table_bread.drop_duplicates(subset='country',keep='last')

#Merging country codes
table_bread = pd.merge(countrycodes, table_bread, how="left", left_on=['country'],right_on=['country'])
table_bread = table_bread.drop(['A2 (ISO)','NUM (UN)','DIALING CODE','spotifyFlag',],axis=1)

table_bread.head()
# Out:
#           country A3 (UN) currency_ID commodity_purchased  \
# 0     Afghanistan     AFG         AFN               Bread
# 1         Albania     ALB         NaN                 NaN
# 2         Algeria     DZA         DZD               Bread
# 3  American Samoa     ASM         NaN                 NaN
# 4         Andorra     AND         NaN                 NaN
#
#   unit_of_goods_measurement  monthly_average_price_paid
# 0                        KG                   44.749375
# 1                       NaN                         NaN
# 2                      Unit                   10.000000
# 3                       NaN                         NaN
# 4                       NaN                         NaN

# %% [markdown]
# #### Wheat
# * Defined criteria and filtered data for the first food item chosen: wheat
# * Merged the datasets in order to have standard Country ID associated to the table.
# * Cleaned up the data for irrelevant columns

# %%
#filtering table for all rows with the commodity
table_wheat = table[table.commodity_purchased.str.contains('Wheat', case=False)]

#sorting the list
table_wheat = table_wheat.sort_values(by=['country','monthly_average_price_paid'],ascending=True,na_position='first')

#dropping duplicated, keeping item with highest price (=last)
table_wheat = table_wheat.drop_duplicates(subset='country',keep='last')

#Merging country codes
table_wheat = pd.merge(countrycodes, table_wheat, how="left", left_on=['country'],right_on=['country'])
table_wheat = table_wheat.drop(['A2 (ISO)','NUM (UN)','DIALING CODE','spotifyFlag',],axis=1)

table_wheat.head()
# Out:
#           country A3 (UN) currency_ID commodity_purchased  \
# 0     Afghanistan     AFG         AFN               Wheat
# 1         Albania     ALB         NaN                 NaN
# 2         Algeria     DZA         NaN                 NaN
# 3  American Samoa     ASM         NaN                 NaN
# 4         Andorra     AND         NaN                 NaN
#
#   unit_of_goods_measurement  monthly_average_price_paid
# 0                        KG                   24.075078
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN

# %% [markdown]
# #### Rice
# * Defined criteria and filtered data for the first food item chosen: rice
# * Merged the datasets in order to have standard Country ID associated to the table.
# * Cleaned up the data for irrelevant columns

# %%
#filtering table for all rows with the commodity
table_rice = table[table.commodity_purchased.str.contains('Rice', case=False)]

#sorting the list
table_rice = table_rice.sort_values(by=['country','monthly_average_price_paid'],ascending=True,na_position='first')

#removing items different from KG
#table_rice=table_rice.loc[table['unit_of_goods_measurement']=="KG",\
#                      ['country','currency_ID','commodity_purchased','unit_of_goods_measurement','monthly_average_price_paid']]

#dropping duplicated, keeping item with highest price (=last)
table_rice = table_rice.drop_duplicates(subset='country',keep='last')

#Merging country codes
table_rice = pd.merge(countrycodes, table_rice, how="left", left_on=['country'],right_on=['country'])
table_rice = table_rice.drop(['A2 (ISO)','NUM (UN)','DIALING CODE','spotifyFlag',],axis=1)

table_rice.head()
# Out:
#           country A3 (UN) currency_ID commodity_purchased  \
# 0     Afghanistan     AFG         AFN  Rice (low quality)
# 1         Albania     ALB         NaN                 NaN
# 2         Algeria     DZA         DZD                Rice
# 3  American Samoa     ASM         NaN                 NaN
# 4         Andorra     AND         NaN                 NaN
#
#   unit_of_goods_measurement  monthly_average_price_paid
# 0                        KG                   41.392708
# 1                       NaN                         NaN
# 2                        KG                  106.250000
# 3                       NaN                         NaN
# 4                       NaN                         NaN

# %% [markdown]
# ### 2) TRANSFORM: GLOBAL FOOD PRICE - Main table creation
#
# * Merge the three tables above into a single one.
# * Clean up data for duplicate columns.
# * Rename columns for compliance with SQL language standard for header name.
# * Standardize index column by Country ID.

# %%
#Merging 3 tables into one.
table_food = pd.merge(table_bread, table_rice, how="left", on=['country'],suffixes=('','y'))
table_food = table_food.drop(['A3 (UN)y','currency_IDy'],axis=1)

table_food = table_food.rename(columns={'commodity_purchased':'commodity_purchased_bread',\
                                        'unit_of_goods_measurement':'unit_of_goods_measurement_bread',\
                                        'monthly_average_price_paid':'monthly_average_price_paid_bread',\
                                        'commodity_purchasedy':'commodity_purchased_rice',\
                                        'unit_of_goods_measurementy':'unit_of_goods_measurement_rice',\
                                        'monthly_average_price_paidy':'monthly_average_price_paid_rice'})

table_food = pd.merge(table_food, table_wheat, how="left", on=['country'],suffixes=('','y'))
table_food = table_food.drop(['A3 (UN)y','currency_IDy'],axis=1)

table_food = table_food.rename(columns={'commodity_purchased':'commodity_purchased_wheat',\
                                        'unit_of_goods_measurement':'unit_of_goods_measurement_wheat',\
                                        'monthly_average_price_paid':'monthly_average_price_paid_wheat'})

table_food = table_food.rename(columns={"A3 (UN)": "country_code"})

# %%
table_food
# Out:
#                                   country country_code currency_ID  \
# 0                             Afghanistan          AFG         AFN
# 1                                 Albania          ALB         NaN
# 2                                 Algeria          DZA         DZD
# 3                          American Samoa          ASM         NaN
# 4                                 Andorra          AND         NaN
# 5                                  Angola          AGO         NaN
# 6                                Anguilla          AIA         NaN
# 7                              Antarctica          ATA         NaN
# 8                     Antigua and Barbuda          ATG         NaN
# 9                               Argentina          ARG         NaN
# 10                                Armenia          ARM         AMD
# 11                                  Aruba          ABW         NaN
# 12                              Australia          AUS         NaN
# 13                                Austria          AUT         NaN
# 14                             Azerbaijan          AZE         NaN
# 15                                Bahamas          BHS         NaN
# 16                                Bahrain          BHR         NaN
# 17                             Bangladesh          BGD         NaN
# 18                               Barbados          BRB         NaN
# 19                                Belarus          BLR         NaN
# 20                                Belgium          BEL         NaN
# 21                                 Belize          BLZ         NaN
# 22                                  Benin          BEN         NaN
# 23                                Bermuda          BMU         NaN
# 24                                 Bhutan          BTN         NaN
# 25                                Bolivia          BOL         BOB
# 26                                Bonaire          BES         NaN
# 27                 Bosnia and Herzegovina          BIH         NaN
# 28                               Botswana          BWA         NaN
# 29                          Bouvet Island          BVT         NaN
# ..                                    ...          ...         ...
# 218           United Republic of Tanzania          TZA         NaN
# 219                              Thailand          THA         NaN
# 220                           Timor-Leste          TLS         NaN
# 221                                  Togo          TGO         NaN
# 222                               Tokelau          TKL         NaN
# 223                                 Tonga          TON         NaN
# 224                   Trinidad and Tobago          TTO         NaN
# 225                               Tunisia          TUN         NaN
# 226                                Turkey          TUR         TRY
# 227                          Turkmenistan          TKM         NaN
# 228              Turks and Caicos Islands          TCA         NaN
# 229                                Tuvalu          TUV         NaN
# 230                                Uganda          UGA         NaN
# 231                               Ukraine          UKR         UAH
# 232                  United Arab Emirates          ARE         NaN
# 233                        United Kingdom          GBR         NaN
# 234                         United States          USA         NaN
# 235  United States Minor Outlying Islands          UMI         NaN
# 236                               Uruguay          URY         NaN
# 237                            Uzbekistan          UZB         NaN
# 238                               Vanuatu          VUT         NaN
# 239                             Venezuela          VEN         NaN
# 240                              Viet Nam          VNM         NaN
# 241                British Virgin Islands          VGB         NaN
# 242                     US Virgin Islands          VIR         NaN
# 243                     Wallis and Futuna          WLF         NaN
# 244                        Western Sahara          ESH         NaN
# 245                                 Yemen          YEM         NaN
# 246                                Zambia          ZMB         NaN
# 247                              Zimbabwe          ZWE         NaN
#
#     commodity_purchased_bread unit_of_goods_measurement_bread  \
# 0                       Bread                              KG
# 1                         NaN                             NaN
# 2                       Bread                            Unit
# 3                         NaN                             NaN
# 4                         NaN                             NaN
# 5                         NaN                             NaN
# 6                         NaN                             NaN
# 7                         NaN                             NaN
# 8                         NaN                             NaN
# 9                         NaN                             NaN
# 10   Bread (high grade flour)                              KG
# 11                        NaN                             NaN
# 12                        NaN                             NaN
# 13                        NaN                             NaN
# 14                        NaN                             NaN
# 15                        NaN                             NaN
# 16                        NaN                             NaN
# 17                        NaN                             NaN
# 18                        NaN                             NaN
# 19                        NaN                             NaN
# 20                        NaN                             NaN
# 21                        NaN                             NaN
# 22                        NaN                             NaN
# 23                        NaN                             NaN
# 24                        NaN                             NaN
# 25              Bread (wheat)                            Unit
# 26                        NaN                             NaN
# 27                        NaN                             NaN
# 28                        NaN                             NaN
# 29                        NaN                             NaN
# ..                        ...                             ...
# 218                       NaN                             NaN
# 219                       NaN                             NaN
# 220                       NaN                             NaN
# 221                       NaN                             NaN
# 222                       NaN                             NaN
# 223                       NaN                             NaN
# 224                       NaN                             NaN
# 225                       NaN                             NaN
# 226            Bread (common)                              KG
# 227                       NaN                             NaN
# 228                       NaN                             NaN
# 229                       NaN                             NaN
# 230                       NaN                             NaN
# 231             Bread (wheat)                            Loaf
# 232                       NaN                             NaN
# 233                       NaN                             NaN
# 234                       NaN                             NaN
# 235                       NaN                             NaN
# 236                       NaN                             NaN
# 237                       NaN                             NaN
# 238                       NaN                             NaN
# 239                       NaN                             NaN
# 240                       NaN                             NaN
# 241                       NaN                             NaN
# 242                       NaN                             NaN
# 243                       NaN                             NaN
# 244                       NaN                             NaN
# 245                       NaN                             NaN
# 246                       NaN                             NaN
# 247                       NaN                             NaN
#
#      monthly_average_price_paid_bread commodity_purchased_rice  \
# 0                           44.749375       Rice (low quality)
# 1                                 NaN                      NaN
# 2                           10.000000                     Rice
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# 5                                 NaN                      NaN
# 6                                 NaN                      NaN
# 7                                 NaN                      NaN
# 8                                 NaN                      NaN
# 9                                 NaN                      NaN
# 10                         488.773585             Rice (white)
# 11                                NaN                      NaN
# 12                                NaN                      NaN
# 13                                NaN                      NaN
# 14                                NaN                      NaN
# 15                                NaN                      NaN
# 16                                NaN                      NaN
# 17                                NaN            Rice (coarse)
# 18                                NaN                      NaN
# 19                                NaN                      NaN
# 20                                NaN                      NaN
# 21                                NaN                      NaN
# 22                                NaN          Rice (imported)
# 23                                NaN                      NaN
# 24                                NaN                      NaN
# 25                           0.458990      Rice (good quality)
# 26                                NaN                      NaN
# 27                                NaN                      NaN
# 28                                NaN                      NaN
# 29                                NaN                      NaN
# ..                                ...                      ...
# 218                               NaN                     Rice
# 219                               NaN                      NaN
# 220                               NaN             Rice (local)
# 221                               NaN                      NaN
# 222                               NaN                      NaN
# 223                               NaN                      NaN
# 224                               NaN                      NaN
# 225                               NaN                      NaN
# 226                          3.373333                     Rice
# 227                               NaN                      NaN
# 228                               NaN                      NaN
# 229                               NaN                      NaN
# 230                               NaN                      NaN
# 231                         10.539988                     Rice
# 232                               NaN                      NaN
# 233                               NaN                      NaN
# 234                               NaN                      NaN
# 235                               NaN                      NaN
# 236                               NaN                      NaN
# 237                               NaN                      NaN
# 238                               NaN                      NaN
# 239                               NaN                      NaN
# 240                               NaN                      NaN
# 241                               NaN                      NaN
# 242                               NaN                      NaN
# 243                               NaN                      NaN
# 244                               NaN                      NaN
# 245                               NaN          Rice (imported)
# 246                               NaN             Rice (local)
# 247                               NaN                      NaN
#
#     unit_of_goods_measurement_rice  monthly_average_price_paid_rice  \
# 0                               KG                        41.392708
# 1                              NaN                              NaN
# 2                               KG                       106.250000
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# 5                              NaN                              NaN
# 6                              NaN                              NaN
# 7                              NaN                              NaN
# 8                              NaN                              NaN
# 9                              NaN                              NaN
# 10                              KG                       546.320755
# 11                             NaN                              NaN
# 12                             NaN                              NaN
# 13                             NaN                              NaN
# 14                             NaN                              NaN
# 15                             NaN                              NaN
# 16                             NaN                              NaN
# 17                              KG                        29.265000
# 18                             NaN                              NaN
# 19                             NaN                              NaN
# 20                             NaN                              NaN
# 21                             NaN                              NaN
# 22                              KG                       486.047619
# 23                             NaN                              NaN
# 24                             NaN                              NaN
# 25                       Cuartilla                        23.230909
# 26                             NaN                              NaN
# 27                             NaN                              NaN
# 28                             NaN                              NaN
# 29                             NaN                              NaN
# ..                             ...                              ...
# 218                         100 KG                    158375.459425
# 219                            NaN                              NaN
# 220                             KG                         2.000000
# 221                            NaN                              NaN
# 222                            NaN                              NaN
# 223                            NaN                              NaN
# 224                            NaN                              NaN
# 225                            NaN                              NaN
# 226                             KG                         6.047500
# 227                            NaN                              NaN
# 228                            NaN                              NaN
# 229                            NaN                              NaN
# 230                            NaN                              NaN
# 231                             KG                        15.938645
# 232                            NaN                              NaN
# 233                            NaN                              NaN
# 234                            NaN                              NaN
# 235                            NaN                              NaN
# 236                            NaN                              NaN
# 237                            NaN                              NaN
# 238                            NaN                              NaN
# 239                            NaN                              NaN
# 240                            NaN                              NaN
# 241                            NaN                              NaN
# 242                            NaN                              NaN
# 243                            NaN                              NaN
# 244                            NaN                              NaN
# 245                             KG                       413.286957
# 246                             KG                        13.760755
# 247                            NaN                              NaN
#
#     commodity_purchased_wheat unit_of_goods_measurement_wheat  \
# 0                       Wheat                              KG
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
# 5                         NaN                             NaN
# 6                         NaN                             NaN
# 7                         NaN                             NaN
# 8                         NaN                             NaN
# 9                         NaN                             NaN
# 10                Wheat flour                              KG
# 11                        NaN                             NaN
# 12                        NaN                             NaN
# 13                        NaN                             NaN
# 14                        NaN                             NaN
# 15                        NaN                             NaN
# 16                        NaN                             NaN
# 17                Wheat flour                              KG
# 18                        NaN                             NaN
# 19                        NaN                             NaN
# 20                        NaN                             NaN
# 21                        NaN                             NaN
# 22                        NaN                             NaN
# 23                        NaN                             NaN
# 24                        NaN                             NaN
# 25              Bread (wheat)                            Unit
# 26                        NaN                             NaN
# 27                        NaN                             NaN
# 28                        NaN                             NaN
# 29                        NaN                             NaN
# ..                        ...                             ...
# 218                       NaN                             NaN
# 219                       NaN                             NaN
# 220                       NaN                             NaN
# 221                       NaN                             NaN
# 222                       NaN                             NaN
# 223                       NaN                             NaN
# 224                       NaN                             NaN
# 225                       NaN                             NaN
# 226               Wheat flour                              KG
# 227                       NaN                             NaN
# 228                       NaN                             NaN
# 229                       NaN                             NaN
# 230                       NaN                             NaN
# 231           Buckwheat grits                              KG
# 232                       NaN                             NaN
# 233                       NaN                             NaN
# 234                       NaN                             NaN
# 235                       NaN                             NaN
# 236                       NaN                             NaN
# 237                       NaN                             NaN
# 238                       NaN                             NaN
# 239                       NaN                             NaN
# 240                       NaN                             NaN
# 241                       NaN                             NaN
# 242                       NaN                             NaN
# 243                       NaN                             NaN
# 244                       NaN                             NaN
# 245               Wheat flour                              KG
# 246                       NaN                             NaN
# 247                     Wheat                              KG
#
#      monthly_average_price_paid_wheat
# 0                           24.075078
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                         231.858491
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                          32.015972
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                           0.458990
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ..                                ...
# 218                               NaN
# 219                               NaN
# 220                               NaN
# 221                               NaN
# 222                               NaN
# 223                               NaN
# 224                               NaN
# 225                               NaN
# 226                          2.848333
# 227                               NaN
# 228                               NaN
# 229                               NaN
# 230                               NaN
# 231                         30.471185
# 232                               NaN
# 233                               NaN
# 234                               NaN
# 235                               NaN
# 236                               NaN
# 237                               NaN
# 238                               NaN
# 239                               NaN
# 240                               NaN
# 241                               NaN
# 242                               NaN
# 243                               NaN
# 244                               NaN
# 245                        167.695364
# 246                               NaN
# 247                          0.504167
#
# [248 rows x 12 columns]

# %%
table_food.set_index("country_code", inplace=True)

# %%
table_food
# Out:
#                                            country currency_ID  \
# country_code
# AFG                                    Afghanistan         AFN
# ALB                                        Albania         NaN
# DZA                                        Algeria         DZD
# ASM                                 American Samoa         NaN
# AND                                        Andorra         NaN
# AGO                                         Angola         NaN
# AIA                                       Anguilla         NaN
# ATA                                     Antarctica         NaN
# ATG                            Antigua and Barbuda         NaN
# ARG                                      Argentina         NaN
# ARM                                        Armenia         AMD
# ABW                                          Aruba         NaN
# AUS                                      Australia         NaN
# AUT                                        Austria         NaN
# AZE                                     Azerbaijan         NaN
# BHS                                        Bahamas         NaN
# BHR                                        Bahrain         NaN
# BGD                                     Bangladesh         NaN
# BRB                                       Barbados         NaN
# BLR                                        Belarus         NaN
# BEL                                        Belgium         NaN
# BLZ                                         Belize         NaN
# BEN                                          Benin         NaN
# BMU                                        Bermuda         NaN
# BTN                                         Bhutan         NaN
# BOL                                        Bolivia         BOB
# BES                                        Bonaire         NaN
# BIH                         Bosnia and Herzegovina         NaN
# BWA                                       Botswana         NaN
# BVT                                  Bouvet Island         NaN
# ...                                            ...         ...
# TZA                    United Republic of Tanzania         NaN
# THA                                       Thailand         NaN
# TLS                                    Timor-Leste         NaN
# TGO                                           Togo         NaN
# TKL                                        Tokelau         NaN
# TON                                          Tonga         NaN
# TTO                            Trinidad and Tobago         NaN
# TUN                                        Tunisia         NaN
# TUR                                         Turkey         TRY
# TKM                                   Turkmenistan         NaN
# TCA                       Turks and Caicos Islands         NaN
# TUV                                         Tuvalu         NaN
# UGA                                         Uganda         NaN
# UKR                                        Ukraine         UAH
# ARE                           United Arab Emirates         NaN
# GBR                                 United Kingdom         NaN
# USA                                  United States         NaN
# UMI           United States Minor Outlying Islands         NaN
# URY                                        Uruguay         NaN
# UZB                                     Uzbekistan         NaN
# VUT                                        Vanuatu         NaN
# VEN                                      Venezuela         NaN
# VNM                                       Viet Nam         NaN
# VGB                         British Virgin Islands         NaN
# VIR                              US Virgin Islands         NaN
# WLF                              Wallis and Futuna         NaN
# ESH                                 Western Sahara         NaN
# YEM                                          Yemen         NaN
# ZMB                                         Zambia         NaN
# ZWE                                       Zimbabwe         NaN
#
#              commodity_purchased_bread unit_of_goods_measurement_bread  \
# country_code
# AFG                              Bread                              KG
# ALB                                NaN                             NaN
# DZA                              Bread                            Unit
# ASM                                NaN                             NaN
# AND                                NaN                             NaN
# AGO                                NaN                             NaN
# AIA                                NaN                             NaN
# ATA                                NaN                             NaN
# ATG                                NaN                             NaN
# ARG                                NaN                             NaN
# ARM           Bread (high grade flour)                              KG
# ABW                                NaN                             NaN
# AUS                                NaN                             NaN
# AUT                                NaN                             NaN
# AZE                                NaN                             NaN
# BHS                                NaN                             NaN
# BHR                                NaN                             NaN
# BGD                                NaN                             NaN
# BRB                                NaN                             NaN
# BLR                                NaN                             NaN
# BEL                                NaN                             NaN
# BLZ                                NaN                             NaN
# BEN                                NaN                             NaN
# BMU                                NaN                             NaN
# BTN                                NaN                             NaN
# BOL                      Bread (wheat)                            Unit
# BES                                NaN                             NaN
# BIH                                NaN                             NaN
# BWA                                NaN                             NaN
# BVT                                NaN                             NaN
# ...                                ...                             ...
# TZA                                NaN                             NaN
# THA                                NaN                             NaN
# TLS                                NaN                             NaN
# TGO                                NaN                             NaN
# TKL                                NaN                             NaN
# TON                                NaN                             NaN
# TTO                                NaN                             NaN
# TUN                                NaN                             NaN
# TUR                     Bread (common)                              KG
# TKM                                NaN                             NaN
# TCA                                NaN                             NaN
# TUV                                NaN                             NaN
# UGA                                NaN                             NaN
# UKR                      Bread (wheat)                            Loaf
# ARE                                NaN                             NaN
# GBR                                NaN                             NaN
# USA                                NaN                             NaN
# UMI                                NaN                             NaN
# URY                                NaN                             NaN
# UZB                                NaN                             NaN
# VUT                                NaN                             NaN
# VEN                                NaN                             NaN
# VNM                                NaN                             NaN
# VGB                                NaN                             NaN
# VIR                                NaN                             NaN
# WLF                                NaN                             NaN
# ESH                                NaN                             NaN
# YEM                                NaN                             NaN
# ZMB                                NaN                             NaN
# ZWE                                NaN                             NaN
#
#               monthly_average_price_paid_bread commodity_purchased_rice  \
# country_code
# AFG                                  44.749375       Rice (low quality)
# ALB                                        NaN                      NaN
# DZA                                  10.000000                     Rice
# ASM                                        NaN                      NaN
# AND                                        NaN                      NaN
# AGO                                        NaN                      NaN
# AIA                                        NaN                      NaN
# ATA                                        NaN                      NaN
# ATG                                        NaN                      NaN
# ARG                                        NaN                      NaN
# ARM                                 488.773585             Rice (white)
# ABW                                        NaN                      NaN
# AUS                                        NaN                      NaN
# AUT                                        NaN                      NaN
# AZE                                        NaN                      NaN
# BHS                                        NaN                      NaN
# BHR                                        NaN                      NaN
# BGD                                        NaN            Rice (coarse)
# BRB                                        NaN                      NaN
# BLR                                        NaN                      NaN
# BEL                                        NaN                      NaN
# BLZ                                        NaN                      NaN
# BEN                                        NaN          Rice (imported)
# BMU                                        NaN                      NaN
# BTN                                        NaN                      NaN
# BOL                                   0.458990      Rice (good quality)
# BES                                        NaN                      NaN
# BIH                                        NaN                      NaN
# BWA                                        NaN                      NaN
# BVT                                        NaN                      NaN
# ...                                        ...                      ...
# TZA                                        NaN                     Rice
# THA                                        NaN                      NaN
# TLS                                        NaN             Rice (local)
# TGO                                        NaN                      NaN
# TKL                                        NaN                      NaN
# TON                                        NaN                      NaN
# TTO                                        NaN                      NaN
# TUN                                        NaN                      NaN
# TUR                                   3.373333                     Rice
# TKM                                        NaN                      NaN
# TCA                                        NaN                      NaN
# TUV                                        NaN                      NaN
# UGA                                        NaN                      NaN
# UKR                                  10.539988                     Rice
# ARE                                        NaN                      NaN
# GBR                                        NaN                      NaN
# USA                                        NaN                      NaN
# UMI                                        NaN                      NaN
# URY                                        NaN                      NaN
# UZB                                        NaN                      NaN
# VUT                                        NaN                      NaN
# VEN                                        NaN                      NaN
# VNM                                        NaN                      NaN
# VGB                                        NaN                      NaN
# VIR                                        NaN                      NaN
# WLF                                        NaN                      NaN
# ESH                                        NaN                      NaN
# YEM                                        NaN          Rice (imported)
# ZMB                                        NaN             Rice (local)
# ZWE                                        NaN                      NaN
#
#              unit_of_goods_measurement_rice  monthly_average_price_paid_rice  \
# country_code
# AFG                                      KG                        41.392708
# ALB                                     NaN                              NaN
# DZA                                      KG                       106.250000
# ASM                                     NaN                              NaN
# AND                                     NaN                              NaN
# AGO                                     NaN                              NaN
# AIA                                     NaN                              NaN
# ATA                                     NaN                              NaN
# ATG                                     NaN                              NaN
# ARG                                     NaN                              NaN
# ARM                                      KG                       546.320755
# ABW                                     NaN                              NaN
# AUS                                     NaN                              NaN
# AUT                                     NaN                              NaN
# AZE                                     NaN                              NaN
# BHS                                     NaN                              NaN
# BHR                                     NaN                              NaN
# BGD                                      KG                        29.265000
# BRB                                     NaN                              NaN
# BLR                                     NaN                              NaN
# BEL                                     NaN                              NaN
# BLZ                                     NaN                              NaN
# BEN                                      KG                       486.047619
# BMU                                     NaN                              NaN
# BTN                                     NaN                              NaN
# BOL                               Cuartilla                        23.230909
# BES                                     NaN                              NaN
# BIH                                     NaN                              NaN
# BWA                                     NaN                              NaN
# BVT                                     NaN                              NaN
# ...                                     ...                              ...
# TZA                                  100 KG                    158375.459425
# THA                                     NaN                              NaN
# TLS                                      KG                         2.000000
# TGO                                     NaN                              NaN
# TKL                                     NaN                              NaN
# TON                                     NaN                              NaN
# TTO                                     NaN                              NaN
# TUN                                     NaN                              NaN
# TUR                                      KG                         6.047500
# TKM                                     NaN                              NaN
# TCA                                     NaN                              NaN
# TUV                                     NaN                              NaN
# UGA                                     NaN                              NaN
# UKR                                      KG                        15.938645
# ARE                                     NaN                              NaN
# GBR                                     NaN                              NaN
# USA                                     NaN                              NaN
# UMI                                     NaN                              NaN
# URY                                     NaN                              NaN
# UZB                                     NaN                              NaN
# VUT                                     NaN                              NaN
# VEN                                     NaN                              NaN
# VNM                                     NaN                              NaN
# VGB                                     NaN                              NaN
# VIR                                     NaN                              NaN
# WLF                                     NaN                              NaN
# ESH                                     NaN                              NaN
# YEM                                      KG                       413.286957
# ZMB                                      KG                        13.760755
# ZWE                                     NaN                              NaN
#
#              commodity_purchased_wheat unit_of_goods_measurement_wheat  \
# country_code
# AFG                              Wheat                              KG
# ALB                                NaN                             NaN
# DZA                                NaN                             NaN
# ASM                                NaN                             NaN
# AND                                NaN                             NaN
# AGO                                NaN                             NaN
# AIA                                NaN                             NaN
# ATA                                NaN                             NaN
# ATG                                NaN                             NaN
# ARG                                NaN                             NaN
# ARM                        Wheat flour                              KG
# ABW                                NaN                             NaN
# AUS                                NaN                             NaN
# AUT                                NaN                             NaN
# AZE                                NaN                             NaN
# BHS                                NaN                             NaN
# BHR                                NaN                             NaN
# BGD                        Wheat flour                              KG
# BRB                                NaN                             NaN
# BLR                                NaN                             NaN
# BEL                                NaN                             NaN
# BLZ                                NaN                             NaN
# BEN                                NaN                             NaN
# BMU                                NaN                             NaN
# BTN                                NaN                             NaN
# BOL                      Bread (wheat)                            Unit
# BES                                NaN                             NaN
# BIH                                NaN                             NaN
# BWA                                NaN                             NaN
# BVT                                NaN                             NaN
# ...                                ...                             ...
# TZA                                NaN                             NaN
# THA                                NaN                             NaN
# TLS                                NaN                             NaN
# TGO                                NaN                             NaN
# TKL                                NaN                             NaN
# TON                                NaN                             NaN
# TTO                                NaN                             NaN
# TUN                                NaN                             NaN
# TUR                        Wheat flour                              KG
# TKM                                NaN                             NaN
# TCA                                NaN                             NaN
# TUV                                NaN                             NaN
# UGA                                NaN                             NaN
# UKR                    Buckwheat grits                              KG
# ARE                                NaN                             NaN
# GBR                                NaN                             NaN
# USA                                NaN                             NaN
# UMI                                NaN                             NaN
# URY                                NaN                             NaN
# UZB                                NaN                             NaN
# VUT                                NaN                             NaN
# VEN                                NaN                             NaN
# VNM                                NaN                             NaN
# VGB                                NaN                             NaN
# VIR                                NaN                             NaN
# WLF                                NaN                             NaN
# ESH                                NaN                             NaN
# YEM                        Wheat flour                              KG
# ZMB                                NaN                             NaN
# ZWE                              Wheat                              KG
#
#               monthly_average_price_paid_wheat
# country_code
# AFG                                  24.075078
# ALB                                        NaN
# DZA                                        NaN
# ASM                                        NaN
# AND                                        NaN
# AGO                                        NaN
# AIA                                        NaN
# ATA                                        NaN
# ATG                                        NaN
# ARG                                        NaN
# ARM                                 231.858491
# ABW                                        NaN
# AUS                                        NaN
# AUT                                        NaN
# AZE                                        NaN
# BHS                                        NaN
# BHR                                        NaN
# BGD                                  32.015972
# BRB                                        NaN
# BLR                                        NaN
# BEL                                        NaN
# BLZ                                        NaN
# BEN                                        NaN
# BMU                                        NaN
# BTN                                        NaN
# BOL                                   0.458990
# BES                                        NaN
# BIH                                        NaN
# BWA                                        NaN
# BVT                                        NaN
# ...                                        ...
# TZA                                        NaN
# THA                                        NaN
# TLS                                        NaN
# TGO                                        NaN
# TKL                                        NaN
# TON                                        NaN
# TTO                                        NaN
# TUN                                        NaN
# TUR                                   2.848333
# TKM                                        NaN
# TCA                                        NaN
# TUV                                        NaN
# UGA                                        NaN
# UKR                                  30.471185
# ARE                                        NaN
# GBR                                        NaN
# USA                                        NaN
# UMI                                        NaN
# URY                                        NaN
# UZB                                        NaN
# VUT                                        NaN
# VEN                                        NaN
# VNM                                        NaN
# VGB                                        NaN
# VIR                                        NaN
# WLF                                        NaN
# ESH                                        NaN
# YEM                                 167.695364
# ZMB                                        NaN
# ZWE                                   0.504167
#
# [248 rows x 11 columns]

# %% [markdown]
# #### Note:
#
# A decision was made to not drop null values, assuming this database structure can be updated in future with refreshed data. It is to say, in case data misssing today for a given country becomes available, it is would be easier to update the field for that country rather than create a entire new row or column. Or ultimately, it is also easy to drop Null values in other analysis.

# %% [markdown]
# ### 2) TRANSFORM: GLOBAL FOOD PRICE
# ### At this step, these columns were manually created in the schema for the SQL database tables.

# %%
table_food.columns
# Out:
# Index(['country', 'currency_ID', 'commodity_purchased_bread',
#        'unit_of_goods_measurement_bread', 'monthly_average_price_paid_bread',
#        'commodity_purchased_rice', 'unit_of_goods_measurement_rice',
#        'monthly_average_price_paid_rice', 'commodity_purchased_wheat',
#        'unit_of_goods_measurement_wheat', 'monthly_average_price_paid_wheat'],
#       dtype='object')

# %% [markdown]
# ### 3) LOAD
#
# #### Comment on additional work done in SQL
#
# The pandas dataframes were loaded into MYSQL using SQL Alchemy (establishing a connection between Jupyter NB and MYSQL).  A MYSQL database (agriculture_db) was created and three tables were created—cereal_yield, agiculture_land, and table_food.
#
# An inner join was written selecting each of the relevant columns and joining the two WB tables on the common column of country code [country_code] and then joining that with the table_food table.  It should be noted that this resulted in many null values in the columns.  Various joins (right, left, inner) in MYSQL were performed as examples that demonstrates that exact type of join will affect the number of rows of the table and are dependent on the data analyses that might be employed.

# %% [markdown]
# ### 3) LOAD: CONNECTING TO SQL DB

# %% [markdown]
# ### At this point, the database was created in SQL. See the SQL query used in Git Hub
# #### https://github.com/messagetorafael/groupproject2/blob/master/agriculture.sql

# %%
#change root to my mysql user name and my sql password
rds_connection_string = "root:[suppressed]@localhost/agriculture_db"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %%
# confirm the tables were created successfully
engine.table_names()
# Out:
# ['agriculture_land', 'cereal_yield', 'table_food']

# %% [markdown]
# ### 3) LOAD: LOAD DATA TO SQL Database tables
#
#
#
# #### WORLD BANK - Issues found
# The two main dataframes were loaded into tables created in MYSQL (as indicated above).  However, when they were loaded a Transform issue arose. The datatype in percent of land devoted to agriculture in pandas was a float of  2 digits plus 6 decimal places (i.e., a percentage with a lot of decimal places).
#
# Because the MYSQL table column was original designated as “decimal” these decimal place values were truncated.  For example, 11.111111 was rendered 11 percent in SQL.  As a result, we had to update the MYSQL table column as DECIMAL (8,6) which preserved the data.

# %%
cereal_yield_df.to_sql(name='cereal_yield', con=engine, if_exists='append', index=True)

# %%
agriculture_land_df.to_sql(name='agriculture_land', con=engine, if_exists='append', index=True)

# %%
table_food.to_sql(name='table_food', con=engine, if_exists='append', index=True)
# Out:
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 1")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 1")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 1")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 11")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 11")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 11")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 18")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 18")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 23")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 26")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 26")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 26")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 36")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 37")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 38")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 43")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 48")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 48")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 50")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 50")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 51")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 51")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 53")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 59")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 61")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 61")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 65")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 65")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 66")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 70")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 70")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 80")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 80")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 83")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 93")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 93")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 95")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 95")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 98")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 102")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 102")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 103")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 113")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 113")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 115")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 120")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 120")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 121")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 123")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 123")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 123")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_bread' at row 124")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 124")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 125")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 132")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 132")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 133")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 136")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 140")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 140")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 151")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 152")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_rice' at row 155")
#   result = self._query(query)
# C:\Users\BahMN\Anaconda3\envs\PythonWebMongo\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'monthly_average_price_paid_wheat' at row 155")
#   result = self._query(query)
